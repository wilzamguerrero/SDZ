# %%
import os
import shutil
from IPython.display import clear_output, Image, display, HTML
from IPython.utils import capture
import requests
import importlib.util
COLOR_CYAN = '\033[96;1;38;5;51m'
COLOR_WHITE = '\033[97m'
COLOR_RESET = '\033[0m'

#install Python 3.10.6 in terminal - !python --version
"""
conda deactivate default
conda deactivate studiolab
conda env remove -n default
conda env remove -n studiolab

conda create -n py3106 python=3.10.6 -y
conda activate py3106
conda install ipykernel -y
python -m ipykernel install --user --name py3106 --display-name "Python 3.10.6"
"""

def opcion1():
    print(COLOR_CYAN + "WAIT A MOMENT WHILE THE INSTALLATION FINISH" + COLOR_RESET)
    # !ln -vs /tmp ~/tmp
    
    # %cd /home/studio-lab-user

    #!conda install -c conda-forge libglib -y & conda update -n base conda -y

    # !pip install -q --upgrade torchsde
    # !pip install -q --upgrade pip
    # !pip install -q --upgrade psutil
    # !pip install -q pytz
    # !pip install pyngrok
    #!pip install requests
    #!pip install -q tensorflow
    
    # %conda update -q -n base conda
    # %conda install -q -c conda-forge gputil
    # %conda install -q -y aria2
    # %conda install -q -y glib
    # %pip install -q opencv-python-headless huggingface-hub
    # !pip3 install --upgrade requests
    # !pip install -q torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 torchtext==0.15.2 torchdata==0.6.1 --extra-index-url https://download.pytorch.org/whl/cu118 -U
    # !pip install -q xformers==0.0.20 triton==2.0.0 -U

    #!pip install opencv-python-headless ; pip install  opencv-contrib-python ; pip install opencv-python
    #!pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
    #!pip install -q xformers==0.0.20 triton==2.0.0 -U
    #!pip install insightface==0.7.3
    #!pip install onnx==1.14.0
    #!pip install onnxruntime==1.15.0

    # %env TF_CPP_MIN_LOG_LEVEL=1
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
    # !mv stable-diffusion-webui SDZ
    # %cd /home/studio-lab-user
    # !git clone https://github.com/comfyanonymous/ComfyUI
    # !mv ComfyUI SDZC

    #Config
    # %cd /home/studio-lab-user/SDZ

    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/notification.mp3 -O notification.mp3
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_user.css -O user.css
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/styles.csv
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_config.json -O config.json
    #!pip install -r /home/studio-lab-user/SDZ/requirements_versions.txt
    
    # %cd /home/studio-lab-user/SDZC
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/extra_model_paths.yaml
    # !pip install -r /home/studio-lab-user/SDZC/requirements.txt
    
    # !pip cache purge
    # !rm -rf ~/.cache
    # %conda clean --all -y

    
    clear_output()
    print(COLOR_CYAN + "SDZ INSTALLED" + COLOR_RESET)


def extensions_code():
    # %conda install -q -y aria2

    folderext = '/home/studio-lab-user/SDZ/extensions'

    if os.path.exists(folderext):
        shutil.rmtree(folderext)

    os.mkdir(folderext)

    # !ln -vs /tmp ~/tmp
    #
    #!mkdir -p /tmp/outputs
    #!rm -rd ~/SDZ/outputs
    #!ln -vs /tmp/outputs /home/studio-lab-user/SDZ/outputs

    # !mkdir -p /tmp/insightface
    # !rm -rd ~/SDZ/models/insightface
    # !ln -vs /tmp/insightface /home/studio-lab-user/SDZ/models/insightface
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/Extras/roopz/inswapper_128.onnx -d /home/studio-lab-user/SDZ/models/insightface -o inswapper_128.onnx

    # !mkdir -p /tmp/Codeformer
    # !rm -rd ~/SDZ/models/Codeformer
    # !ln -vs /tmp/Codeformer /home/studio-lab-user/SDZ/models/Codeformer

    # !mkdir -p /tmp/GFPGAN
    # !rm -rd ~/SDZ/models/GFPGAN
    # !ln -vs /tmp/GFPGAN /home/studio-lab-user/SDZ/models/GFPGAN

    # !mkdir -p /tmp/deepbooru
    # !rm -rd ~/SDZ/models/deepbooru
    # !ln -vs /tmp/deepbooru /home/studio-lab-user/SDZ/models/deepbooru

    #Checkpoint
    # !mkdir -p /tmp/models
    # !rm -rd ~/SDZ/models/Stable-diffusion
    # !ln -vs /tmp/models /home/studio-lab-user/SDZ/models/Stable-diffusion

    #ClipVision2
    # !mkdir -p /tmp/clip_vision2
    # !rm -rd ~/SDZ/models/clip_vision
    # !ln -vs /tmp/clip_vision2 /home/studio-lab-user/SDZ/models/clip_vision

    #controlnet
    # !mkdir -p /tmp/controlnet_models
    # !rm -rd ~/SDZ/extensions/sd-webui-controlnet/models
    # !ln -vs /tmp/controlnet_models /home/studio-lab-user/SDZ/extensions/sd-webui-controlnet/models

    #extensions
    # %cd ~/SDZ/extensions

    # !git clone https://github.com/etherealxx/batchlinks-webui

    # !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111
    # !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete
    # !git clone https://github.com/zanllp/sd-webui-infinite-image-browsing
    #!git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser
    # !git clone https://github.com/yankooliveira/sd-webui-photopea-embed
    # !git clone https://github.com/Physton/sd-webui-prompt-all-in-one
    # !git clone https://github.com/ArtVentureX/sd-webui-agent-scheduler
    # !git clone https://github.com/richrobber2/canvas-zoom
    # !git clone https://github.com/viyiviyi/stable-diffusion-webui-zoomimage
    # !git clone https://github.com/wcde/sd-webui-kohya-hiresfix
    # !git clone https://github.com/Mikubill/sd-webui-controlnet
    #!git clone https://github.com/djbielejeski/a-person-mask-generator
    #!git clone https://github.com/Flyguygx/sd-webui-panorama-tools
    #!git clone https://github.com/0xbitches/sd-webui-lcm

    """
    # !git clone https://github.com/diffus-me/sd-webui-facefusion
    # !pip install -r /home/studio-lab-user/SDZ/extensions/sd-webui-facefusion/requirements.txt
    # %conda install ffmpeg
    # !pip install onnxruntime
    # !pip install torchsde --upgrade
    # !pip install onnxruntime --upgrade

    # !wget --timestamping -P /home/studio-lab-user/SDZ/extensions/sd-webui-facefusion/facefusion https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/fus/predictor.py
    # !wget --timestamping -P /home/studio-lab-user/SDZ/extensions/sd-webui-facefusion/facefusion https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/fus/utilities.py
    """

    """
    # !git clone https://github.com/Gourieff/sd-webui-reactor
    # !sed -i 's/package: str, version: str | None = None, strict: bool = True/package: str, version: str = None, strict: bool = True/g' /home/studio-lab-user/SDZ/extensions/sd-webui-reactor/install.py

    #!git clone https://github.com/glucauze/sd-webui-faceswaplab
    #!sed -i '17,44d' /home/studio-lab-user/SDZ/extensions/sd-webui-faceswaplab/scripts/faceswaplab_utils/imgutils.py
    #!sed -i '17s/.*/    return False/' /home/studio-lab-user/SDZ/extensions/sd-webui-faceswaplab/scripts/faceswaplab_utils/imgutils.py

    """

    #!git clone https://github.com/s0md3v/sd-webui-roop
    #!sed -i 's|shapes.append(chunk\["score"\] > 0.7)|shapes.append(chunk["score"] > 99999)|' /home/studio-lab-user/SDZ/extensions/sd-webui-roop/scripts/cimage.py

    """
    #!git clone https://github.com/continue-revolution/sd-webui-animatediff
    #!mkdir -p /tmp/animatediff_models
    #!rm -rd ~/SDZ/extensions/sd-webui-animatediff/model
    #!ln -vs /tmp/animatediff_models /home/studio-lab-user/SDZ/extensions/sd-webui-animatediff/model
    #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt -d /home/studio-lab-user/SDZ/extensions/sd-webui-animatediff/model -o mm_sd_v15_v2.ckpt
    """
    #!git clone https://github.com/deforum-art/deforum-for-automatic1111-webui.git
    #!git clone https://github.com/DavideAlidosi/sd-webui-controlnet-animatediff
    #!git clone https://github.com/DavideAlidosi/sd-webui-animatediff-for-ControlNet
    #!git clone https://github.com/NextDiffusion/next-view

    #!git clone https://github.com/ddpn08/kohya-sd-scripts-webui.git
    #!git clone https://github.com/d8ahazard/sd_dreambooth_extension.git
    #!gdown https://acortar.link/Js6Hu0 -O roopu.zip && unzip -n roopu.zip && rm roopu.zip
    #!git clone https://github.com/thygate/stable-diffusion-webui-depthmap-script.git
    #!git clone https://github.com/graemeniedermayer/stable-diffusion-webui-normalmap-script.git
    #!git clone https://github.com/dustysys/ddetailer.git
    #!git clone https://github.com/novitalabs/sd-webui-cleaner
    # !git clone https://github.com/Bing-su/adetailer.git
    #!https://github.com/A-I-Channel/sdw-wd14-tagger
    #!git clone https://github.com/A-I-Channel/AI_Channel_Theme
    #!git clone https://github.com/volotat/SD-CN-Animation.git
    #!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-promptgen.git
    #!git clone https://github.com/imrayya/stable-diffusion-webui-Prompt_Generator.git
    #!git clone https://github.com/canisminor1990/sd-web-ui-kitchen-theme.git
    #!git clone https://github.com/v8hid/infinite-zoom-automatic1111-webui.git
    #!git clone https://github.com/Extraltodeus/depthmap2mask.git

    # !git clone https://github.com/huchenlei/sd-webui-openpose-editor
    # !git clone https://github.com/fkunn1326/openpose-editor.git
    #!git clone https://github.com/nonnonstop/sd-webui-3d-open-pose-editor.git
    #!git clone https://github.com/hnmr293/posex.git

    #https://github.com/if-ai/IF_prompt_MKR.git
    #https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111.git
    #https://github.com/Coyote-A/ultimate-upscale-for-automatic1111.git
    #https://github.com/d8ahazard/sd_dreambooth_extension.git
    #https://github.com/hako-mikan/sd-webui-regional-prompter.git

    #!git clone https://github.com/A-I-Channel/explorer-image
    #!git clone https://github.com/A-I-Channel/public-link
    #!git clone https://github.com/opparco/stable-diffusion-webui-two-shot.git
    #!git clone https://github.com/opparco/stable-diffusion-webui-composable-lora.git
    #!git clone https://github.com/thygate/stable-diffusion-webui-depthmap-script
    #!git clone https://github.com/jexom/sd-webui-depth-lib.git
    #!git clone https://github.com/alemelis/sd-webui-ar.git
    #!git clone https://github.com/butaixianran/Stable-Diffusion-Webui-Civitai-Helper.git
    #!git clone https://github.com/Scholar01/sd-webui-mov2mov.git
    #!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-pixelization.git
    #!git clone https://github.com/s9roll7/ebsynth_utility.git
    #!git clone https://github.com/journey-ad/sd-webui-bilingual-localization.git
    #!git clone https://github.com/hako-mikan/sd-webui-supermerger.git
    #!git clone https://github.com/zero01101/openOutpaint-webUI-extension.git
    #!git clone https://github.com/Bing-su/sd-webui-tunnels.git
    #!git clone https://github.com/bbc-mc/sdweb-merge-block-weighted-gui.git
    #!git clone https://github.com/bbc-mc/sdweb-xyplus.git
    #!git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon.git
    #!git clone https://github.com/arenatemp/stable-diffusion-webui-model-toolkit.git
    #!git clone https://github.com/fishslot/video_loopback_for_webui.git
    #!git clone https://github.com/mcmonkeyprojects/sd-dynamic-thresholding.git
    #!git clone https://github.com/kohya-ss/sd-webui-additional-networks.git
    #!git clone https://github.com/hnmr293/sd-webui-llul.git
    #!git clone https://github.com/hnmr293/sd-webui-cutoff.git
    #!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg
    #!git clone https://github.com/camenduru/stable-diffusion-webui-huggingface
    #!git clone https://github.com/AIrjen/OneButtonPrompt.git
    #!git clone https://github.com/Uminosachi/sd-webui-inpaint-anything.git
    #!wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py
    #!git clone https://github.com/CiaraStrawberry/TemporalKit.git
    #!git clone https://github.com/novitalabs/sd-webui-cleaner
    #!git clone https://github.com/n714/sd-webui-generate-button

    #!git clone https://github.com/sunnyark/civitai-shortcut
    #!gdown https://acortar.link/52XJvM -O dragGAN.zip && unzip -n dragGAN.zip && rm dragGAN.zip
    #!gdown https://acortar.link/TQvkPk -O loopback_scaler.zip && unzip -n loopback_scaler.zip && rm loopback_scaler.zip
    #!gdown https://acortar.link/c7W5YY -O 3D_editor.zip && unzip -n 3D_editor.zip && rm 3D_editor.zip
    #!gdown https://acortar.link/KayyQV -O 3D_loader.zip && unzip -n 3D_loader.zip && rm 3D_loader.zip
    #!gdown https://acortar.link/e5cxQ0 -O txt_img_3d.zip && unzip -n txt_img_3d.zip && rm txt_img_3d.zip
    #!gdown https://acortar.link/US0GK0 -O qrcode_gen.zip && unzip -n qrcode_gen.zip && rm qrcode_gen.zip
    #!gdown https://acortar.link/wyLuCY -O qrcode_tool.zip && unzip -n qrcode_tool.zip && rm qrcode_tool.zip
    #!gdown https://acortar.link/IjtgWB -O animatediff.zip && unzip -n animatediff.zip && rm animatediff.zip
    #!gdown https://acortar.link/11b1Vu -O refiner.zip && unzip -n refiner.zip && rm refiner.zip

    #!git clone https://github.com/GeorgLegato/sd-webui-panorama-viewer
    #!git clone https://github.com/ljleb/sd-webui-neutral-prompt
    #!git clone https://github.com/ashen-sensored/sd_webui_masactrl
    #!git clone https://github.com/SpenserCai/sd-webui-deoldify
    #!git clone https://github.com/Artiprocher/sd-webui-fastblend
    #!git clone https://github.com/ashen-sensored/sd_webui_SAG
    #!git clone https://github.com/ModelSurge/sd-webui-comfyui
    #!git clone https://github.com/antfu/sd-webui-qrcode-toolkit
    #!git clone https://github.com/NeoGraph-K/sd-webui-ddsd
    #!git clone https://github.com/Em1tSan/sd-webui-roop-unlock

    #https://github.com/victorchall/EveryDream2trainer

    folderext2 = '/home/studio-lab-user/SDZC/custom_nodes'

    if os.path.exists(folderext2):
        shutil.rmtree(folderext2)

    os.mkdir(folderext2)
    
    # %cd /home/studio-lab-user/SDZC/custom_nodes
    # !git clone https://github.com/Lerc/canvas_tab
    # !git clone https://github.com/ltdrdata/ComfyUI-Manager
    # !git clone https://github.com/0xbitches/ComfyUI-LCM
    # !git clone https://github.com/ssitu/ComfyUI_UltimateSDUpscale --recursive
    # !git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts
    # !git clone https://github.com/city96/SD-Latent-Upscaler
    # !git clone https://github.com/LucianoCirino/efficiency-nodes-comfyui
    # !git clone https://github.com/BlenderNeko/ComfyUI_ADV_CLIP_emb
    # !git clone https://github.com/ssitu/ComfyUI_NestedNodeBuilder
    # !git clone https://github.com/RockOfFire/ComfyUI_Comfyroll_CustomNodes
    # !git clone https://github.com/Acly/comfyui-tooling-nodes
    # !git clone https://github.com/cubiq/ComfyUI_IPAdapter_plus
    # !git clone https://github.com/Fannovel16/comfyui_controlnet_aux
    #!git clone https://github.com/chrisgoringe/cg-use-everywhere
    
    # %cd /home/studio-lab-user/SDZC/web/scripts
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/ComfyUI_app.js -O app.js
    # %cd /home/studio-lab-user/SDZC/web
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/ComfyUI_user.css -O user.css

    # !mkdir -p /tmp/ESRGAN
    # !rm -rd ~/SDZ/models/ESRGAN
    # !ln -vs /tmp/ESRGAN /home/studio-lab-user/SDZ/models/ESRGAN
    # %cd ~/SDZ/models/ESRGAN

    #Upscaler
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/1x_NMKD-BrightenRedux_200k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/1x_NMKDDetoon_97500_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/1x_NMKD-YandereInpaint_375000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/1x_NoiseToner-Poisson-Detailed_108000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/1x_NoiseToner-Uniform-Detailed_100000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_CountryRoads_377000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_fatal_Anime_500000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_Fatality_Comix_260000_G.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/4x_UniversalUpscalerV2-Neutral_115000_swaG.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/4x_UniversalUpscalerV2-Sharp_101000_G.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/4x_UniversalUpscalerV2-Sharper_103000_G.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/Legacy/4x_UniversalUpscaler-Detailed_155000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/Legacy/4x_UniversalUpscaler-Soft_190000_G.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_foolhardy_Remacri.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x-UltraSharp.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NickelbackFS_72000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-Siax_200k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKDSuperscale_Artisoft_120000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-Superscale-Artisoftject_210000_G.pth
    ##!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-Superscale-SP_178000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-UltraYandere_300k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-UltraYandere-Lite_280k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_NMKD-YandereNeoXL_200k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_RealisticRescaler_100000_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_Valar_v1.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4xPSNR.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/8x_NMKD-Superscale_150000_G.pth
    # !wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/8x_NMKD-Typescale_175k.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/8xPSNR.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/16xPSNR.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/A_ESRGAN_Single.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/BSRGAN.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/BSRGANx2.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/BSRNet.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/LADDIER1_282500_G.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/lollypop.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/sudo_rife4_269.662_testV1_scale1.pth
    #!wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/WaifuGAN_v3_30000.pth
    #wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/GFPGAN/GFPGANv1.3.pth
    #wget --timestamping https://huggingface.co/uwg/upscaler/resolve/main/GFPGAN/GFPGANv1.4.pth

    #Vae
    # !mkdir -p /tmp/VAE
    # !rm -rd ~/SDZ/models/VAE
    # !ln -vs /tmp/VAE /home/studio-lab-user/SDZ/models/VAE
    # %cd ~/SDZ/models/VAE
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/VAE/vae-ft-mse-840000-ema-pruned.ckpt -o vae-ft-mse-840000-ema-pruned.ckpt
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/VAE/sdxl-vae-fp16.safetensors -o sdxl-vae-fp16.safetensors

    #Embeddings
    # !mkdir -p /tmp/embeddings
    # !rm -rd ~/SDZ/embeddings
    # !ln -vs /tmp/embeddings /home/studio-lab-user/SDZ/embeddings
    # %cd ~/SDZ/embeddings

    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/150491 # edgQuality.pt
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/bad-hands-5.pt
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/easynegative.safetensors
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/EasyNegativeV2.safetensors
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/FastNegativeEmbedding.pt
    #!wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/bad-artist-anime.pt
    #!wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/bad-artist.pt
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/negativeXL.safetensors

    #Lora
    # !mkdir -p /tmp/Lora
    # !rm -rd ~/SDZ/models/Lora
    # !ln -vs /tmp/Lora /home/studio-lab-user/SDZ/models/Lora
    # %cd ~/SDZ/models/Lora
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/87153   -o add_detail.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/86247   -o flat2.safetensors
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/epiNoiseoffset_v2.safetensors
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/theovercomer8sContrastFix_sd15.safetensors
    # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/to8sHighKeyLORSDZ15SD2_sd15.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/63006
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/117467
    # !wget --timestamping https://huggingface.co/casque/detailed_eye-10/resolve/main/detailed_eye-10.safetensors
    #!wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/ClothingAdjuster2.safetensors
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/62833

    # !pip cache purge
    # !rm -rf ~/.cache

def opcion2():
    clear_output()
    while True:  
        print(" ")
        print(COLOR_CYAN + "SDZ Install Models Version:" + COLOR_RESET)
        print(" ")
        print("1. SDZ 1.5")
        print("2. SDZ XL")
        print("0. Back to Main Menu")
        print(" ")

        sub_opcion = input("Select an option: ")

        if sub_opcion == "1":
            clear_output()
            print(COLOR_CYAN + "WAIT A MOMENT WHILE THE TEMPORAL INSTALLATION OF THE MODELS 1.5 FINISH" + COLOR_RESET)
            extensions_code()

            # %cd ~/SDZ/models/Stable-diffusion
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v2.safetensors -o d2.safetensors
            #!wget --timestamping https://huggingface.co/SimianLuo/LCM_Dreamshaper_v7/resolve/main/LCM_Dreamshaper_v7_4k.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/XpucT/Deliberate/resolve/main/Deliberate_v3.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/143906
            #!wget --no-check-certificate --content-disposition https://civitai.com/api/download/models/15236

            # %cd ~/SDZ/extensions/sd-webui-controlnet/models

            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -o control_v11p_sd15_canny_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -o control_v11p_sd15_openpose_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -o control_v11f1p_sd15_depth_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -o control_v11p_sd15_normalbae_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -o control_v11p_sd15_mlsd_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -o control_v11p_sd15_lineart_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -o control_v11p_sd15_softedge_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -o control_v11p_sd15_scribble_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -o control_v11p_sd15_seg_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -o control_v11e_sd15_shuffle_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -o control_v11f1e_sd15_tile_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -o control_v11p_sd15_inpaint_fp16.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -o control_v11e_sd15_ip2p_fp16.safetensors

            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_canny-fp16.safetensors -o t2iadapter_canny-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_color-fp16.safetensors -o t2iadapter_color-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_depth-fp16.safetensors -o t2iadapter_depth-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_keypose-fp16.safetensors -o t2iadapter_keypose-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_openpose-fp16.safetensors -o t2iadapter_openpose-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_seg-fp16.safetensors -o t2iadapter_seg-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_sketch-fp16.safetensors -o t2iadapter_sketch-fp16.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_style-fp16.safetensors -o t2iadapter_style-fp16.safetensors

            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/85428 -o lightingBasedPicture_v10.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/111973 -o controlnetQRPatternQR_v20.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus-face_sd15.bin -o ip-adapter-plus-face_sd15.pth
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus_sd15.bin -o ip-adapter-plus_sd15.pth
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15.bin -o ip-adapter_sd15.pth
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15_light.bin -o ip-adapter_sd15_light.pth

            # !mkdir -p /tmp/clip_vision
            # !rm -rd ~/SDZ/extensions/sd-webui-controlnet/annotator/downloads/clip_vision
            # !ln -vs /tmp/clip_vision /home/studio-lab-user/SDZ/extensions/sd-webui-controlnet/annotator/downloads/clip_vision
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/Annotators/resolve/main/clip_g.pth -d /home/studio-lab-user/SDZ/extensions/sd-webui-controlnet/annotator/downloads/clip_vision -o clip_g.pth

            """""""""""""""
    
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition  https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/pytorch_model.bin -d /home/studio-lab-user/SDZC/models/clip_vision/SD1.5 -o pytorch_model.bin
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter_sd15.safetensors -d /home/studio-lab-user/SDZC/custom_nodes/ComfyUI_IPAdapter_plus/models -o ip-adapter_sd15.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/latent-consistency/lcm-lora-sdv1-5/resolve/main/pytorch_lora_weights.safetensors -d /home/studio-lab-user/SDZ/models/Lora -o lcm-lora-sdv1-5.safetensors

            """""""""""""""
            
            # !pip cache purge
            # !rm -rf ~/.cache
            # %conda clean --all -y
            break 

            clear_output()
            print(COLOR_CYAN + "MODELS 1.5 INSTALLED" + COLOR_RESET)

            
        if sub_opcion == "2":
            clear_output()
            print(COLOR_CYAN + "WAIT A MOMENT WHILE THE TEMPORAL INSTALLATION OF THE MODELS XL FINISH" + COLOR_RESET)
            extensions_code()

            # %cd ~/SDZ/models/Stable-diffusion
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/190908
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/166909
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://civitai.com/api/download/models/246043

            # %cd ~/SDZ/extensions/sd-webui-controlnet/models

            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/diffusers_xl_canny_small.safetensors -o diffusers_xl_canny_small.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/diffusers_xl_depth_small.safetensors -o diffusers_xl_depth_small.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/ip-adapter_xl.pth -o ip-adapter_xl.pth
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_blur.safetensors -o kohya_controllllite_xl_blur.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_blur_anime.safetensors -o kohya_controllllite_xl_blur_anime.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_blur_anime_beta.safetensors -o kohya_controllllite_xl_blur_anime_beta.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_canny.safetensors -o kohya_controllllite_xl_canny.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_canny_anime.safetensors -o kohya_controllllite_xl_canny_anime.safetensors

            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_depth.safetensors -o kohya_controllllite_xl_depth.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_depth_anime.safetensors -o kohya_controllllite_xl_depth_anime.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_openpose_anime.safetensors -o kohya_controllllite_xl_openpose_anime.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_openpose_anime_v2.safetensors -o kohya_controllllite_xl_openpose_anime_v2.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_scribble_anime.safetensors -o kohya_controllllite_xl_scribble_anime.safetensors

            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_canny_128lora.safetensors -o sai_xl_canny_128lora.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_depth_128lora.safetensors -o sai_xl_depth_128lora.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_recolor_128lora.safetensors -o sai_xl_recolor_128lora.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_sketch_128lora.safetensors -o sai_xl_sketch_128lora.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sargezt_xl_depth.safetensors -o sargezt_xl_depth.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sargezt_xl_depth_faid_vidit.safetensors -o sargezt_xl_depth_faid_vidit.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sargezt_xl_depth_zeed.safetensors -o sargezt_xl_depth_zeed.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sargezt_xl_softedge.safetensors -o sargezt_xl_softedge.safetensors

            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_canny.safetensors -o t2i-adapter_diffusers_xl_canny.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_depth_midas.safetensors -o t2i-adapter_diffusers_xl_depth_midas.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_depth_zoe.safetensors -o t2i-adapter_diffusers_xl_depth_zoe.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_lineart.safetensors -o t2i-adapter_diffusers_xl_lineart.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_openpose.safetensors -o t2i-adapter_diffusers_xl_openpose.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_sketch.safetensors -o t2i-adapter_diffusers_xl_sketch.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_xl_canny.safetensors -o t2i-adapter_xl_canny.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_xl_openpose.safetensors -o t2i-adapter_xl_openpose.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_xl_sketch.safetensors -o t2i-adapter_xl_sketch.safetensors
            #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/thibaud_xl_openpose.safetensors -o thibaud_xl_openpose.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/thibaud_xl_openpose_256lora.safetensors -o thibaud_xl_openpose_256lora.safetensors

            """""""""""""""
        
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter_sdxl_vit-h.safetensors -d /home/studio-lab-user/SDZC/custom_nodes/ComfyUI_IPAdapter_plus/models -o ip-adapter_sdxl_vit-h.safetensors
            # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --content-disposition https://huggingface.co/latent-consistency/lcm-lora-sdxl/resolve/main/pytorch_lora_weights.safetensors -d /home/studio-lab-user/SDZ/models/Lora -o lcm-lora-sdxl.safetensors
            
            """""""""""""""

            # !pip cache purge
            # !rm -rf ~/.cache
            # %conda clean --all -y
            break 

            clear_output()
            print(COLOR_CYAN + "MODELS XL INSTALLED" + COLOR_RESET)

        elif sub_opcion == "0":
            break  # Sal del menú de actualización y regresa al menú principal
        else:
            clear_output()
            print(COLOR_CYAN + "INVALID OPTION. PLEASE SELECT A VALID OPTION" + COLOR_RESET)

    
def opcion3():
    # %cd /home/studio-lab-user/SDZ
    clear_output()

    print(COLOR_WHITE + "CREATE NGROK TOKEN >>> https://dashboard.ngrok.com/get-started/your-authtoken" + COLOR_RESET)
    print(COLOR_CYAN + "SDZ CANT RUN IF YOU ENTER A INVALID NGROK TOKEN" + COLOR_RESET)
    print(" ")
    ngrok_token = input(" Insert ngrok token:")
    clear_output()
    print(COLOR_CYAN + "SDZ RUNNING" + COLOR_RESET)
    SDZ_Args = f"--ngrok {ngrok_token} --api --enable-insecure-extension-access --xformers --theme=dark --no-download-sd-model --disable-safe-unpickle"
    # !COMMANDLINE_ARGS="{SDZ_Args}" python launch.py 2>&1 | grep -o 'URL: https://[^ ]*'
    # !pip cache purge
    # !rm -rf ~/.cache
    clear_output()
    print(COLOR_CYAN + "SDZ FINISH" + COLOR_RESET)
    
def opcion4():
    # %cd /home/studio-lab-user/SDZC
    clear_output()

    print(COLOR_WHITE + "CREATE NGROK TOKEN >>> https://dashboard.ngrok.com/get-started/your-authtoken" + COLOR_RESET)
    print(COLOR_CYAN + "SDZ CANT RUN IF YOU ENTER A INVALID NGROK TOKEN" + COLOR_RESET)
    print(" ")
    ngrok_token = input(" Insert ngrok token:")
    clear_output()
    print(COLOR_CYAN + "SDZ RUNNING" + COLOR_RESET)
    from threading import Timer
    from queue import Queue
    from pyngrok import ngrok

    def ngrok_tunnel(port,queue,auth_token):
        ngrok.set_auth_token(auth_token)
        url = ngrok.connect(port)
        queue.put(url)

    ngrok_output_queue = Queue()
    ngrok_thread = Timer(2, ngrok_tunnel, args=(8188, ngrok_output_queue, ngrok_token))
    ngrok_thread.start()
    ngrok_thread.join()
    # !rm -r /home/studio-lab-user/.ngrok2
    print(ngrok_output_queue.get())

    SDZ_Args = f"--ngrok {ngrok_token} --preview-method auto --enable-cors-header --use-pytorch-cross-attention"
    # !COMMANDLINE_ARGS="{SDZ_Args}" python main.py 2>&1 | grep -o 'URL: https://[^ ]*'
    # !pip cache purge
    # !rm -rf ~/.cache
    clear_output()
    print(COLOR_CYAN + "SDZ FINISH" + COLOR_RESET)
       
def opcion0():
    clear_output()
    print(COLOR_CYAN + "GOODBYE!" + COLOR_RESET)

while True:
    clear_output()
    ruta_imagen = 'https://github.com/wilzamguerrero/SDZ/raw/main/SDZ_custom/icon/SDZanim2.gif'
    display(Image(url=ruta_imagen, width=70, height=70))
    #print(" ")
    print(COLOR_CYAN + "SDZ MENU:" + COLOR_RESET)
    print(" ")
    print("1. Install SDZ")
    print("2. Easy Models")
    print("3. Run SDZ A1111")
    print("4. Run SDZ COMFYUI")
    print("5. Tools")
    print("0. Exit")
    print(" ")
    opcion = input(" Select an option:")
    
    if opcion == "1":
        opcion1()
        
    elif opcion == "2":
        opcion2()
        
    elif opcion == "3":
        opcion3()
    
    elif opcion == "4":
        opcion4()
    
    elif opcion == "5":
        clear_output()
        while True:  
            print(" ")
            print(COLOR_CYAN + "SDZ Tools:" + COLOR_RESET)
            print(" ")
            print("1. Update SDZ")
            print("2. Install DreamBooth")
            print("3. Compress Output Folder")
            print("4. List all Folder and files")
            print("5. Check Space Disk")
            print("6. Clean Cache")
            print("7. Clean Space - Only restart the Jupyter Lab")
            print("8. Delete All - Need restart all the runtime")

            print("0. Back to Main Menu")
            print(" ")

            sub_opcion = input("Select an option: ")

            if sub_opcion == "1":
                clear_output()
                # %cd /home/studio-lab-user/SDZ
                # !git pull
                # %cd /home/studio-lab-user/SDZC
                # !git pull
                clear_output()
                print(COLOR_CYAN + "SDZ UPDATED" + COLOR_RESET)
                
            elif sub_opcion == "2":
                clear_output()
                # %cd /home/studio-lab-user/SDZ/extensions
                # !git clone https://github.com/d8ahazard/sd_dreambooth_extension.git
                # %cd /home/studio-lab-user/SDZ/extensions/sd_dreambooth_extension
                # !pip install -r /home/studio-lab-user/SDZ/extensions/sd_dreambooth_extension/requirements.txt
                clear_output()
                print(COLOR_CYAN + "DREAMBOOTH INSTALLED" + COLOR_RESET)

            elif sub_opcion == "3":
                clear_output()
                import zipfile
                def zip_folder(input_folder, output_folder, max_size_mb=20):
                    # Create the output folder if it doesn't exist
                    os.makedirs(output_folder, exist_ok=True)
                    zip_number = 1
                    current_zip_size = 0
                    current_zip_name = os.path.join(output_folder, f"part_{zip_number}.zip")    
                    with zipfile.ZipFile(current_zip_name, 'w', zipfile.ZIP_DEFLATED) as current_zip:
                        for root, _, files in os.walk(input_folder):
                            for file in files:
                                file_path = os.path.join(root, file)
                                file_size = os.path.getsize(file_path)           
                                # Check if adding the current file exceeds the max size
                                if current_zip_size + file_size > max_size_mb * 1024 * 1024:
                                    # Close the current zip file
                                    current_zip.close()             
                                    # Start a new zip file
                                    zip_number += 1
                                    current_zip_name = os.path.join(output_folder, f"part_{zip_number}.zip")
                                    current_zip = zipfile.ZipFile(current_zip_name, 'w', zipfile.ZIP_DEFLATED)
                                    current_zip_size = 0  
                                # Add the file to the current zip
                                current_zip.write(file_path, os.path.relpath(file_path, input_folder))
                                current_zip_size += file_size
                # Specify the input folder to be zipped
                input_folder = '/home/studio-lab-user/SDZ/outputs'  # Replace with the path to your input folder
                # Specify the output folder where zip files will be saved
                output_folder = '/home/studio-lab-user'  # Replace with the path to your output folder
                # Specify the maximum size for each zip file in MB
                max_size_mb = 200
                # Create zip files with a maximum size of 20MB
                zip_folder(input_folder, output_folder, max_size_mb)
                print(COLOR_CYAN + "COMPRESS OUTPUT FOLDER IN /home/studio-lab-user" + COLOR_RESET)

            elif sub_opcion == "4":
                clear_output()
                # !du -h --max-depth=1 /home/studio-lab-user
                print(COLOR_CYAN + "LIST ALL" + COLOR_RESET)
                
            elif sub_opcion == "5":
                # !pip install -q --upgrade psutil
                clear_output()
                import psutil
                directory = os.getcwd()
                disk_space = psutil.disk_usage(directory)
                total = disk_space.total / (1024 ** 3)
                used = disk_space.used / (1024 ** 3)
                free = disk_space.free / (1024 ** 3)
                clear_output()
                print(COLOR_CYAN + f"TOTAL STORAGE: [ {total:.2f} GB ] USED: [ {used:.2f} GB ] FREE: [ {free:.2f} GB ]" + COLOR_RESET)
                
            elif sub_opcion == "6":
                clear_output()
                # !pip cache purge
                # !rm -rf ~/.cache
                clear_output()
                print(COLOR_CYAN + "CLEANED UNNECESSARY CACHE/FILES" + COLOR_RESET)

            elif sub_opcion == "7":
                clear_output()
                # !rm -r /home/studio-lab-user/.cache
                # !rm -r /home/studio-lab-user/.conda
                # !conda remove -n "env_name" --all
                # !rm -rf /home/studio-lab-user/*

                clear_output()
                print(COLOR_CYAN + "NOW YOU HAVE A CLEAN SPACE, then DO > RESTART JUPYTER LAB" + COLOR_RESET)
                
                
            elif sub_opcion == "8":
                clear_output()
                #!rm -r /home/studio-lab-user/.cache
                #!rm -r /home/studio-lab-user/.conda
                #!conda remove -n "env_name" --all
                #!rm -rf /home/studio-lab-user/*
                # !rm -rf /home/studio-lab-user/
                clear_output()
                print(COLOR_CYAN + "NOW YOU HAVE A CLEAN ENV, then DO > STOP RUNTIME - STAR AGAIN" + COLOR_RESET)
                
            elif sub_opcion == "0":
                break  # Sal del menú de actualización y regresa al menú principal
            else:
                clear_output()
                print(COLOR_CYAN + "INVALID OPTION. PLEASE SELECT A VALID OPTION" + COLOR_RESET)
    
    elif opcion == "0":
        opcion0()
        break
    
    else:
        clear_output()
        print(COLOR_CYAN + "INVALID OPTION. PLEASE SELECT A VALID OPTION" + COLOR_RESET)
