# %% [markdown]
# <a href="https://colab.research.google.com/github/wilzamguerrero/SDZ/blob/main/SDZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/drive.png?raw=true' height="50" alt="netdata"/></center>
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
clear_output()
print('[1;96mDrive Connected ✓')



#import os
#from IPython.display import clear_output

#save_models_dir = "/content/sample_data"#@param {type:"string"}
#os.chdir(save_models_dir)
#url = "" #@param {type:"string"}
#!wget --no-check-certificate --content-disposition $url

#clear_output()
#print('[1;96mModel Save ✓')

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/save.png?raw=true' height="50" alt="netdata"/></center>
from IPython.utils import capture
from IPython.display import clear_output, display, HTML

# !pip install -q udocker
# !udocker --allow-root install
# !udocker --allow-root pull littlepotat/test:latest
# !udocker --allow-root create --name=test littlepotat/test:latest
# !udocker --allow-root setup --nvidia test
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb -O /content/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb


# %cd /root/.udocker/containers/test/ROOT/content/test

# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_user.css -O user.css
# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/styles.csv
#!wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_config.json -O config.json


mosta = 'models/S t a b l e-d i f f u s i o n'
mostaz = mosta.replace(' ', '')

# %cd $mostaz
import os; link = "https://c iv i t ai.com/a pi/download/models/15236"; output_file = "d2.saf ete nsors"; os.system(f"wget --timestamping {link.replace(' ', '')} -O {output_file.replace(' ', '')}")

clear_output()
print('[1;96mRequirements Installed ✓')

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/SDZanim2.gif?raw=true' height="50" alt="netdata"/></center>3
import atexit, requests, subprocess, time, re
from random import randint
from threading import Timer
from queue import Queue
def cloudflared(port, metrics_port, output_queue):
    atexit.register(lambda p: p.terminate(), subprocess.Popen(['cloudflared', 'tunnel', '--url', f'http://127.0.0.1:{port}', '--metrics', f'127.0.0.1:{metrics_port}'], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT))
    attempts, tunnel_url = 0, None
    while attempts < 10 and not tunnel_url:
        attempts += 1
        time.sleep(3)
        try:
            tunnel_url = re.search("(?P<url>https?:\/\/[^\s]+.trycloudflare.com)", requests.get(f'http://127.0.0.1:{metrics_port}/metrics').text).group("url")
        except:
            pass
    if not tunnel_url:
        raise Exception("Can't connect to Cloudflare Edge")
    output_queue.put(tunnel_url)
output_queue, metrics_port = Queue(), randint(8100, 9000)
thread = Timer(2, cloudflared, args=(7860, metrics_port, output_queue))
thread.start()
thread.join()
tunnel_url = output_queue.get()
print(tunnel_url)

#!udocker --allow-root -q run test
# !udocker --allow-root -q run -v /content/drive/MyDrive/AI/Civ:/civ -v /content/drive/MyDrive/AI/ControlNet15:/controlnet15 test

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/save.png?raw=true' height="50" alt="netdata"/></center> 1
from IPython.utils import capture
from IPython.display import clear_output, display, HTML

# !pip install -q udocker
# !udocker --allow-root install
# !udocker --allow-root pull littlepotat/test:latest
# !udocker --allow-root create --name=test littlepotat/test:latest
# !udocker --allow-root setup --nvidia test
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb -O /content/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

clear_output()
print('[1;96mRequirements Installed ✓')

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/save.png?raw=true' height="50" alt="netdata"/></center> 2
from IPython.utils import capture
from IPython.display import clear_output, display, HTML

import os
SDZ_install = "/root/.udocker/containers/test/ROOT/content/test"

SDZ_Extensions = True


#model
#https://civitai.com/api/download/models/156110
#https://civitai.com/api/download/models/15236

#cnet
#https://drive.google.com/file/d/1-1UkHMwBb2SjRiACoYco0nvSr4NmRMwl/view?usp=drive_link
#https://drive.google.com/file/d/1-ZF4EdVnqYVoYHVkxuplpVv-Htq0AebN/view?usp=drive_link


# %cd /root/.udocker/containers/test/ROOT/content/test

# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_user.css -O user.css
# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/styles.csv
#!wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_config.json -O config.json


# %cd extensions

link = "https://github.com/ArtVen tureX/s d-w e b u i-ag ent-sche duler"; os.system(f"git clone {link.replace(' ', '')}")
link = "https://github.com/Coy ote-A/ul tim ate-upscale-for-a u to m a ti c 1 1 1 1"; os.system(f"git clone {link.replace(' ', '')}")
link = "https://github.com/ric hrob ber2/canvas-zoom"; os.system(f"git clone {link.replace(' ', '')}")
link = "https://github.com/vi yiv iyi/s t a b l e-d i f f u s i o n-w e b u i-zoomimage"; os.system(f"git clone {link.replace(' ', '')}")

# %cd /root/.udocker/containers/test/ROOT/content/test/models

#lora
if not os.path.exists('Lora'):
   os.makedirs('Lora')
   # %cd Lora
   if not os.path.exists('epiNoiseoffset_v2.safetensors'):
        # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/Lora/epiNoiseoffset_v2.safetensors
        # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/Lora/theovercomer8sContrastFix_sd15.safetensors
        # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/Lora/to8sHighKeyLORASD15SD2_sd15.safetensors
        # !wget --timestamping --content-disposition https://civitai.com/api/download/models/63006
        # !wget --timestamping --content-disposition https://civitai.com/api/download/models/117467
        # !wget --timestamping --content-disposition https://huggingface.co/casque/detailed_eye-10/resolve/main/detailed_eye-10.safetensors
        # !wget --timestamping --content-disposition https://civitai.com/api/download/models/117955
        # !wget --timestamping --content-disposition https://civitai.com/api/download/models/62833
        # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/Lora/ClothingAdjuster2.safetensors
# %cd ../..

# %cd embeddings
if not os.path.exists('bad-hands-5.pt'):
    # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/bad-hands-5.pt
    # !wget --timestamping --content-disposition https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/easynegative.safetensors
# %cd ..

#upscaler
# %cd /root/.udocker/containers/test/ROOT/content/test/models

if not os.path.exists('ESRGAN'):
    os.makedirs('ESRGAN')
    # %cd ESRGAN

    # !wget --timestamping --content-disposition https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x-UltraSharp.pth
    # !wget --timestamping --content-disposition https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/UniversalUpscaler/4x_UniversalUpscalerV2-Neutral_115000_swaG.pth
    # !wget --timestamping --content-disposition https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_RealisticRescaler_100000_G.pth
    # !wget --timestamping --content-disposition https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/4x_foolhardy_Remacri.pth

clear_output()
print('[1;96mCustomized Installed ✓')

# %% [markdown]
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \
# \

# %%
#@markdown <left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/SDZanim2.gif?raw=true' height="50" alt="netdata"/></center> <a href="https://wilzamguerrero.ml/3c030fffd57c4e3bb4dd62e3971cb6a9"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/how_to_use5.png?raw=true' height="42" alt="netdata"/></center></font></a> <a href="https://zero01101.github.io/openOutpaint/"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/open_out_paint.png?raw=true' height="42" alt="netdata"/></center></font></a> <a href="https://www.painthua.com/"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/paint_hua.png?raw=true' height="42" alt="netdata"/></center></font></a> </a> <a href="https://github.com/ddPn08/kohya-sd-scripts-webui"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/kohya2.png?raw=true' height="42" alt="netdata"/></center></font></a> </a> <a href="https://github.com/Linaqruf/kohya-trainer"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/kohya2.png?raw=true' height="42" alt="netdata"/></center></font></a> </a> <a href="https://zhuyu1997.github.io/open-pose-editor/"><font face='Verdana Regular' color='#80ff3' size='4'><left><img src='https://github.com/wilzamguerrero/SDZ/blob/main/SDZ_custom/icon/save.png?raw=true' height="42" alt="netdata"/></center></font></a> </center></font></a>
import os
import shutil
import sys
import fileinput
import time
from IPython.utils import capture
from IPython.display import clear_output, display, HTML
from datetime import timedelta
from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
from google.colab.output import eval_js

# %cd /content
try:
  start_colab
except:
  start_colab = int(time.time())-5
clear_output()
print("[1;90m") #Cyan text

try:
  output
except:
  print('Checking GPU...', end='')
  output = getoutput('nvidia-smi --query-gpu=gpu_name --format=csv')
  if "name" in output:
    gpu_name = output[5:]
    print('\rCurrent GPU:', gpu_name, flush=True)
  else:
    print('\r\033[91m❎ ERROR: No GPU detected. Please do step below to enable.\n', flush=True)
    display(HTML("<img src='https://i.ibb.co/HC9KH17/NVIDIA-Share-23-01-02-173037.png' width='800px'/>"))
    print('\033[91m\nIf it says "Cannot connect to GPU backend", meaning you\'ve either reached free usage limit. OR there\'s no gpu available.\n\nDon\'t mind me... I\'m destroying your current session for your own good...')
    time.sleep(5)
    from google.colab import runtime
    runtime.unassign()

#@markdown <left><font face='Verdana Regular' color='#00f3f3' size='4'>▣</font>
SDZ_install = "/content"
SDZ_Version = "V1.5"
SDZ_Download_Model = "" #@param ["", "V1.5", "VXL1.0", "Custom_Link"]
SDZ = "SDZ"
SDZ_webui_path = (SDZ_install+'/'+'SDZ'+'/'+'ra/ro/ri/re')
os.chdir(SDZ_install)

SDZ_Model_Init = "" #@param {type:"string"}
SDZ_Models_Dir = "" #@param {type:"string"}
#@markdown <left><font face='Verdana Regular' color='#00f3f3' size='4'>▥</font>

SDZ_sharez = "--share --api --enable-insecure-extension-access --xformers --theme=dark --disable-safe-unpickle --enable-insecure-extension-access --cors-allow-origins=https://www.painthua.com,https://zero01101.github.io"
SDZ_share = " --ckpt=" + SDZ_Model_Init + " --ckpt-dir=" + SDZ_Models_Dir + " " + SDZ_sharez
SDZ_Extensions = True
SDZ_ControlNet = True
SDZ_ControlNet_Model = "" #@param ["", "V1.5", "VXL1.0"]
SDZ_Big_Models = True
SDZ_Upscalers = True
SDZ_Training = "" #@param ["", "New_Dreambooth - Kohya", "Old_Dreambooth"]
SDZ_Args = "--medvram-sdxl" #@param {type:"string"}
#@markdown <left><font face='Verdana Regular' color='#00f3f3' size='4'>◨</font>
SDZ_Continue = False #@param {type:"boolean"}
SDZconfigV2="--config v2-inference-v.yaml"
#share = " --ckpt=" + SDZ_Model_Init + " --ckpt-dir=" + SDZ_Models_Dir + " " + SDZ_Args
share = SDZ_share

#/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
sdxl_patch = False
patches_dir = "/content/SDZ/patches/"
merge_in_vram = False
load_in_vram = False
ram_patch_for_sd2 = False
dpmpp_v2 = False
hypernetworks_dir = False
stable_build = False

# Unpack Repo, Dependencies, Caches
if not os.path.exists("/content/SDZ"):
  start_install = int(time.time())

  install_time = timedelta(seconds=time.time()-start_install)
  time_since_start = timedelta(seconds=time.time()-start_colab)
  clear_output()

print('[1;96mInstalling SDZ ✓')

with capture.capture_output() as cap:

# SDZ_RunSDZ
  if not SDZ_Continue:
    with capture.capture_output() as cap:
      if os.path.exists(SDZ):
        shutil.rmtree(SDZ)
        # %cd /content/SDZ
        # !gdown https://acortar.link/7s6bCl -O er.zip && (mkdir -p ra/ro/ri && unzip -n er.zip -d ra/ro/ri/re && mv ra/ro/ri/re/*/* ra/ro/ri/re/ && rm er.zip)


      if not os.path.exists(SDZ):
        os.makedirs(SDZ)
        os.chdir(SDZ)
        # !gdown https://acortar.link/7s6bCl -O er.zip && (mkdir -p ra/ro/ri && unzip -n er.zip -d ra/ro/ri/re && mv ra/ro/ri/re/*/* ra/ro/ri/re/ && rm er.zip)


      os.chdir(SDZ_webui_path)
      # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_Files.txt
      import os; [os.system(line.strip()) for line in open('/content/SDZ/ra/ro/ri/re/SDZ_Files.txt')]

    #clear_output()
  #print('[1;96mInstalling SDZ ✓')

if SDZ_Continue:
  with capture.capture_output() as cap:
    os.chdir(SDZ_webui_path)
    clear_output()
  print('[1;96mPreparing SDZ Continue ✓')

# SDZ_Requirements
with capture.capture_output() as cap:
  os.chdir(SDZ_webui_path)
  #!apt --fix-broken install
  #!pip install fastapi==0.94.0 -qq
  #!pip install open-clip-torch==2.20.0 -qq --no-deps
  #!pip install openmim
  #!pip install svglib
  #!sudo apt-get install libcairo2-dev
  #!pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
  #pip install -q xformers==0.0.18 triton==2.0.0 -U
  #!pip install gradio

# SDZ_Models
  os.chdir(SDZ_webui_path)
  # %cd /content/SDZ/models/Stable-diffusion

  if SDZ_Download_Model == "Custom_Link":
    custom_linkz = input("Enter Custom Link: ")
    if custom_linkz.strip() != "":
        download_command = f"apt-get install -qq -y aria2 && url=\"{custom_linkz}\" && base_name=$(basename $url) && ((echo $url | grep -q \"drive.google.com\") && gdown --fuzzy $url || ((echo $url | grep -q \"huggingface.co/\") && (hf_token=\"\" && aria2c --console-log-level=error --summary-interval=10 --header=\"Authorization: Bearer $hf_token\" -c -x 16 -k 1M -s 16 $base_name $url)) || aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 $url)"
        os.system(download_command)

  elif SDZ_Download_Model == "V1.5":
    # !apt-get install -qq -y aria2 && url="https://huggingface.co/uwg/modelz_base/resolve/main/Zv1-5-fp16.ckpt" && base_name=$(basename $url) && ((echo $url | grep -q "drive.google.com") && gdown --fuzzy $url || ((echo $url | grep -q "huggingface.co/") && (hf_token="" && aria2c --console-log-level=error --summary-interval=10 --header="Authorization: Bearer $hf_token" -c -x 16 -k 1M -s 16 $base_name $url)) || aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -o v15.ckpt $url)

  elif SDZ_Download_Model == "VXL1.0":
    # !apt-get install -qq -y aria2 && url="https://acortar.link/WNCawM" && base_name=$(basename $url) && ((echo $url | grep -q "drive.google.com") && gdown --fuzzy $url || ((echo $url | grep -q "huggingface.co/") && (hf_token="" && aria2c --console-log-level=error --summary-interval=10 --header="Authorization: Bearer $hf_token" -c -x 16 -k 1M -s 16 $base_name $url)) || aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -o XL1.0vae.safetensors $url)
    # !apt-get install -qq -y aria2 && url="https://acortar.link/mt4XSp" && base_name=$(basename $url) && ((echo $url | grep -q "drive.google.com") && gdown --fuzzy $url || ((echo $url | grep -q "huggingface.co/") && (hf_token="" && aria2c --console-log-level=error --summary-interval=10 --header="Authorization: Bearer $hf_token" -c -x 16 -k 1M -s 16 $base_name $url)) || aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -o XLREF1.0vae.safetensors $url)

  else:
    SDZ_Download_Model = ""
    os.chdir(SDZ_webui_path)

# SDZ_Extensions
  if SDZ_Extensions:
    os.chdir(SDZ_webui_path)
    # %cd models/VAE
    if not os.path.exists('vae-ft-mse-840000-ema-pruned.ckpt'):
      # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/VAE/vae-ft-mse-840000-ema-pruned.ckpt
      # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sdxl_vae/resolve/main/sdxl_vae.safetensors -o sdxl_vae.safetensors
      #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/main/sdxl_vae.safetensors -o sdxl_vae.safetensors
    # %cd ..

    if not os.path.exists('Lora'):
        os.makedirs('Lora')
    # %cd Lora
    if not os.path.exists('epiNoiseoffset_v2.safetensors'):
      # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/epiNoiseoffset_v2.safetensors
      # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/theovercomer8sContrastFix_sd15.safetensors
      # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/to8sHighKeyLORASD15SD2_sd15.safetensors
      # !wget --timestamping https://civitai.com/api/download/models/63006 -O LowRA.safetensors
      # !wget --timestamping https://civitai.com/api/download/models/117467 -O polyhedron_skinny_all.pt
      # !wget --timestamping https://huggingface.co/casque/detailed_eye-10/resolve/main/detailed_eye-10.safetensors
      # !wget --timestamping https://civitai.com/api/download/models/117955 -O topo_v4.safetensors
      #!wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/Lora/ClothingAdjuster2.safetensors
      # !wget --timestamping https://civitai.com/api/download/models/62833 -O add_detail.safetensors
    # %cd ../..

    # %cd embeddings
    if not os.path.exists('bad-hands-5.pt'):
        # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/bad-hands-5.pt
        # !wget --timestamping https://huggingface.co/uwg/modelz_base/resolve/main/embeddings/easynegative.safetensors
    # %cd ..

    # %cd extensions

    link = "https://github.com/etherealxx/batchlinks-web ui"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/Coyote-A/ultimate-upscale-for-automatic1111"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/camenduru/sd-civitai-browser"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/DominikDoom/a1111-sd-web ui-tagcomplete"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/zanllp/sd-web ui-infinite-image-browsing"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/AlUlkesh/stable-diffusion-web ui-images-browser"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/camenduru/sd-web ui-tunnels"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/yankooliveira/sd-web ui-photopea-embed"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/Physton/sd-web ui-prompt-all-in-one"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/P2Enjoy/sd-web ui-roop-uncensored"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/s0md3v/sd-web ui-roop"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/alemelis/sd-web ui-ar"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/richrobber2/canvas-zoom"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/viyiviyi/stable-diffusion-web ui-zoomimage"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/deforum-art/sd-web ui-deforum"; os.system(f"git clone {link.replace(' ', '')}")
    link = "https://github.com/ArtVentureX/sd-web ui-agent-scheduler"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/jtydhr88/sd-canvas-editor"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/thygate/stable-diffusion-web ui-depthmap-script"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Extraltodeus/depthmap2mask"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/graemeniedermayer/stable-diffusion-web ui-normalmap-script"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Bing-su/adetailer"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/volotat/SD-CN-Animation"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Scholar01/sd-web ui-mov2mov"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/AUTOMATIC1111/stable-diffusion-web ui-promptgen"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/imrayya/stable-diffusion-web ui-Prompt_Generator"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/lobehub/sd-web ui-lobe-theme"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/v8hid/infinite-zoom-automatic1111-web ui"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/opparco/stable-diffusion-web ui-two-shot"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/hako-mikan/sd-web ui-regional-prompter"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/opparco/stable-diffusion-web ui-composable-lora"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/jexom/sd-web ui-depth-lib"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/ZhUyU1997/open-pose-editor"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/nonnonstop/sd-web ui-3d-open-pose-editor"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/hnmr293/posex"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/fkunn1326/openpose-editor"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/butaixianran/Stable-Diffusion-Web ui-Civitai-Helper"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/AUTOMATIC1111/stable-diffusion-web ui-pixelization"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/s9roll7/ebsynth_utility"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/journey-ad/sd-web ui-bilingual-localization"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Akegarasu/sd-web ui-model-converter"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/hako-mikan/sd-web ui-supermerger"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/bbc-mc/sdweb-merge-block-weighted-gui"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/arenasys/stable-diffusion-web ui-model-toolkit"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/fishslot/video_loopback_for_web ui"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/mcmonkeyprojects/sd-dynamic-thresholding"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/kohya-ss/sd-web ui-additional-networks"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/hnmr293/sd-web ui-llul"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/hnmr293/sd-web ui-cutoff"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/AUTOMATIC1111/stable-diffusion-web ui-rembg"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/camenduru/stable-diffusion-web ui-huggingface"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/AIrjen/OneButtonPrompt"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Uminosachi/sd-web ui-inpaint-anything"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/CiaraStrawberry/TemporalKit"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/sunnyark/civitai-shortcut"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/aleSheng/sd-web ui-dragGAN-extension"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/Elldreth/loopback_scaler"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/jtydhr88/sd-web ui-3d-editor"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/jtydhr88/sd-3dmodel-loader"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/jtydhr88/sd-web ui-txt-img-to-3d-model"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/missionfloyd/web ui-qrcode-generator"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/antfu/sd-web ui-qrcode-toolkit"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/continue-revolution/sd-web ui-animatediff"; os.system(f"git clone {link.replace(' ', '')}")
    #link = "https://github.com/wcde/sd-web ui-refiner"; os.system(f"git clone {link.replace(' ', '')}")
    # %cd ..

# SDZ_ControlNet
  if SDZ_ControlNet:
    os.chdir(SDZ_webui_path)
    # %cd extensions
    if not os.path.exists('controlnet'):
        # !gdown https://acortar.link/XZ3XnA -O controlnet_Mikubill.zip && (mkdir -p controlnet; unzip -n controlnet_Mikubill.zip -d controlnet && mv controlnet/*/* controlnet/ && rm controlnet_Mikubill.zip)
        #!gdown https://acortar.link/8EU5Ne -O controlnet_AbdullahAlfaraj.zip && (mkdir -p controlnet2; unzip -n controlnet_AbdullahAlfaraj.zip -d controlnet2 && mv controlnet2/*/* controlnet2/ && rm controlnet_AbdullahAlfaraj.zip)

  if SDZ_ControlNet_Model == "V1.5":
    os.chdir(SDZ_webui_path+'/'+'models')
    if not os.path.exists('ControlNet'):
        os.makedirs('ControlNet')
    # %cd ControlNet
    import os; from concurrent.futures import ThreadPoolExecutor; [executor.submit(os.system, line.strip()) for line in open(SDZ_webui_path+'/SDZ_ControlNet_15.txt') if not os.path.exists('control_v11f1p_sd15_depth.pth') for executor in [ThreadPoolExecutor(max_workers=len(open(SDZ_webui_path+'/SDZ_ControlNet_15.txt').readlines()))]];
    # !cp cldm_v15.yaml cldm_v21.yaml {os.path.join(SDZ_webui_path, 'models')}
    # %cd ../..

  elif SDZ_ControlNet_Model == "VXL1.0":
    os.chdir(SDZ_webui_path+'/'+'models')
    if not os.path.exists('ControlNet'):
        os.makedirs('ControlNet')
    # %cd ControlNet
    import os; from concurrent.futures import ThreadPoolExecutor; [executor.submit(os.system, line.strip()) for line in open(SDZ_webui_path+'/SDZ_ControlNet_XL10.txt') if not os.path.exists('controlnet-depth-sdxl-1.0.safetensors') for executor in [ThreadPoolExecutor(max_workers=len(open(SDZ_webui_path+'/SDZ_ControlNet_XL10.txt').readlines()))]];
    # !cp cldm_v15.yaml cldm_v21.yaml {os.path.join(SDZ_webui_path, 'models')}
    # %cd ../..

  else:
    SDZ_ControlNet_Model == ""
    os.chdir(SDZ_webui_path)

# SDZ_Upscalers
  if SDZ_Upscalers:
    os.chdir(SDZ_webui_path+'/'+'models')
    if not os.path.exists('ESRGAN'):
        os.makedirs('ESRGAN')
    # %cd ESRGAN
    import os; from concurrent.futures import ThreadPoolExecutor; [executor.submit(os.system, line.strip()) for line in open(SDZ_webui_path+'/SDZ_Upscalers.txt') if not os.path.exists('4x_UniversalUpscalerV2-Sharper_103000_G.pth') for executor in [ThreadPoolExecutor(max_workers=len(open(SDZ_webui_path+'/SDZ_Upscalers.txt').readlines()))]];

# SDZ_Training
  if SDZ_Training == "New_Dreambooth - Kohya":
    os.chdir(SDZ_webui_path)
    if not os.path.exists('/usr/local/lib/python3.10/site-packages/open_clip'):
      # !wget -N https://github.com/korakot/kora/releases/download/v0.10/py310.sh
      # !bash ./py310.sh -b -f -p /usr/local
      # !python -m ipykernel install --name "py310" --user
      # !pip install open-clip-torch
      # !pip install triton
      # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cuda"):@' /usr/local/lib/python3.10/site-packages/open_clip/factory.py
    # %cd extensions
    # !git clone https://github.com/ddpn08/kohya-sd-scripts-webui.git
    # !git clone https://github.com/d8ahazard/sd_dreambooth_extension.git
    # %cd ..
    # !pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 -f https://download.pytorch.org/whl/cu117/torch_stable.html

  elif SDZ_Training == "Old_Dreambooth":
    os.chdir(SDZ_webui_path)
    if not os.path.exists('/usr/local/lib/python3.10/site-packages/open_clip'):
      # !wget -N https://github.com/korakot/kora/releases/download/v0.10/py310.sh
      # !bash ./py310.sh -b -f -p /usr/local
      # !python -m ipykernel install --name "py310" --user
      # !pip install open-clip-torch
      # !pip install triton
      # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cuda"):@' /usr/local/lib/python3.10/site-packages/open_clip/factory.py

    os.chdir(SDZ_webui_path)
    # !git checkout 1130d5df669911a5c67696be90bccca3ecf5f487
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/config.json
    # !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/user_old.css -O user.css
    # %cd extensions
    # !git clone https://github.com/d8ahazard/sd_dreambooth_extension.git
    # %cd sd_dreambooth_extension
    # !git checkout f9900ccb3ce7025d1c89334e320a1c3b255bbd07
    # %cd ../..

  else:
    SDZ_Training == ""
    os.chdir(SDZ_webui_path)

  if sdxl_patch:
    # !sed -i -e '''/from modules import launch_utils/a\import os''' /content/SDZ/launch.py
    # !sed -i -e '''/        prepare_environment()/a\        os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/SDZ/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/SDZ/launch.py

  if SDZ_Big_Models:
    # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' $SDZ_webui_path'/webui.py'
    # !sed -i "s@map_location='cpu'@map_location='cuda'@" $SDZ_webui_path'/modules/extras.py'
    # !sed -i "s/                    print(strings.en\[\"SHARE_LINK_MESSAGE\"\])/                    print('[1;90m')/" '/usr/local/lib/python3.9/dist-packages/gradio/blocks.py'

  clear_output()
print('[1;90mPreparing SDZ System ✓')
if SDZ_Version == "V1.5":
  # !COMMANDLINE_ARGS="{SDZ_share} {SDZ_Args}" REQS_FILE="requirements_versions.txt" python launch.py

time_since_start = timedelta(seconds=time.time()-start_colab)
print("\n\n[1;96mYou've been running this colab for","%02d:%02d:%02d" % (time_since_start.seconds / 3600, (time_since_start.seconds / 60) % 60, time_since_start.seconds % 60))
print("\n\n")

# %%
# %%capture
import os
import shutil
import zipfile
# %cd /content
# !gdown https://acortar.link/7s6bCl -O er.zip
with zipfile.ZipFile('er.zip', 'r') as zip_ref:
    zip_ref.extractall()
with zipfile.ZipFile('er.zip', 'r') as zip_ref:
    old = zip_ref.namelist()[0]
end = '/content/ra/re/ri/ro/ru'
for archivo in os.listdir(old):
    go = os.path.join(old, archivo)
    shutil.move(go, end)
shutil.rmtree(old)
os.remove('er.zip')
# %cd /content/ra/re/ri/ro/ru
os.makedirs("localizations")
# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/SDZ_user.css -O user.css
# !wget --timestamping https://raw.githubusercontent.com/wilzamguerrero/SDZ/main/SDZ_custom/styles.csv


#!python launch.py --share --api --xformers --theme dark --no-download-sd-model --ckpt-dir /content/drive/MyDrive/AI/Civ
